# %%
import pandas as pd
import re
import ftfy
import numpy as np

# %%
# ==============================================================================
# 1. CONFIGURAÇÕES E CARREGAMENTO
# ==============================================================================
FILE_PATH = r'C:\Users\mlzengo\Documents\TJGO\II SEMESTRE\classe-assuno\data\raw\amostra_processos_classes_recorrentes_27022025.csv'

# Seu arquivo usa # como separador
try:
    df = pd.read_csv(FILE_PATH, sep='#', encoding='utf-8')
    print(f"✓ Dataset carregado com sucesso!")
    print(f"Total de linhas: {len(df)}")
    print(f"Total de colunas: {len(df.columns)}")
    print(f"\nColunas: {df.columns.tolist()}")
    print(f"\nPrimeiras 3 linhas:")
    print(df.head(3))
    
except FileNotFoundError:
    print("Arquivo não encontrado. Verifique o caminho.")
    
except Exception as e:
    print(f"Erro ao carregar: {e}")
# Out:
# ✓ Dataset carregado com sucesso!
# Total de linhas: 53000
# Total de colunas: 4
#
# Colunas: ['numero_processo', 'assunto', 'classe', 'inteiro_teor']
#
# Primeiras 3 linhas:
#              numero_processo  \
# 0  5333922.47.2020.8.09.0000
# 1  5436439.33.2020.8.09.0000
# 2  5451883.09.2020.8.09.0000
#
#                                              assunto  \
# 0                                   Atos Processuais
# 1  Constrição / Penhora / Avaliação / Indisponibi...
# 2  Atos Processuais@Responsabilidade Civil -> Ind...
#
#                           classe  \
# 0  Agravo de Instrumento ( CPC )
# 1  Agravo de Instrumento ( CPC )
# 2  Agravo de Instrumento ( CPC )
#
#                                         inteiro_teor
# 0  >>>>>inicio<<<<<\nEXCELENTÍSSMO SENHOR DESEMBA...
# 1  >>>>>inicio<<<<<\nAlessandra Reis • Julio Mari...
# 2  >>>>>inicio<<<<<\nEXCELENTÍSSIMO SENHOR DESEMB...
