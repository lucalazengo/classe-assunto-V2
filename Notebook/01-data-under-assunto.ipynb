# %%
import pandas as pd
import re
import ftfy
import numpy as np

# %%
# ==============================================================================
# 1. CONFIGURAÇÕES E CARREGAMENTO
# ==============================================================================
FILE_PATH = r'C:\Users\mlzengo\Documents\TJGO\II SEMESTRE\classe-assuno\data\raw\amostra_processos_assuntos_recorrentes_27022025.csv'

# Seu arquivo usa # como separador
try:
    df = pd.read_csv(FILE_PATH, sep='#', encoding='utf-8')
    print(f"✓ Dataset carregado com sucesso!")
    print(f"Total de linhas: {len(df)}")
    print(f"Total de colunas: {len(df.columns)}")
    print(f"\nColunas: {df.columns.tolist()}")
    print(f"\nPrimeiras 3 linhas:")
    print(df.head(3))
    
except FileNotFoundError:
    print("Arquivo não encontrado. Verifique o caminho.")
    
except Exception as e:
    print(f"Erro ao carregar: {e}")
# Out:
# ✓ Dataset carregado com sucesso!
# Total de linhas: 93000
# Total de colunas: 4
#
# Colunas: ['numero_processo', 'assunto', 'classe', 'inteiro_teor']
#
# Primeiras 3 linhas:
#              numero_processo  \
# 0  5299393.38.2023.8.09.0051
# 1  5375398.72.2021.8.09.0051
# 2  5644722.68.2021.8.09.0051
#
#                                              assunto  \
# 0  DIREITO ADMINISTRATIVO E OUTRAS MATÉRIAS DE DI...
# 1  DIREITO ADMINISTRATIVO E OUTRAS MATÉRIAS DE DI...
# 2  DIREITO ADMINISTRATIVO E OUTRAS MATÉRIAS DE DI...
#
#                                               classe  \
# 0  PROCESSO CÍVEL E DO TRABALHO -> Processo de Ex...
# 1  PROCESSO CÍVEL E DO TRABALHO -> Processo de Ex...
# 2  PROCESSO CÍVEL E DO TRABALHO -> Processo de Ex...
#
#                                         inteiro_teor
# 0  >>>>>inicio<<<<<\nPROCURADORIA GERAL DO MUNICI...
# 1  >>>>>inicio<<<<<\nESTADO DE GOIÁS PROCURADORIA...
# 2  >>>>>inicio<<<<<\nPROCURADORIA GERAL DO MUNICI...
